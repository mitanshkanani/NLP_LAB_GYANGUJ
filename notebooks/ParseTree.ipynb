# %%
# Cell 1 - Package Installation (GOOD)
# Install required packages for parse trees
# !pip install nltk
# !pip install stanfordnlp
# !pip install conllu

print("All packages installed successfully!")
# Out:
# Requirement already satisfied: nltk in c:\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: stanfordnlp in c:\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from stanfordnlp) (1.26.4)
# Requirement already satisfied: protobuf in c:\users\mitansh kanani\appdata\roaming\python\python312\site-packages (from stanfordnlp) (6.32.1)
# Requirement already satisfied: requests in c:\users\mitansh kanani\appdata\roaming\python\python312\site-packages (from stanfordnlp) (2.32.3)
# Requirement already satisfied: torch>=1.0.0 in c:\anaconda3\lib\site-packages (from stanfordnlp) (2.8.0)
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (from stanfordnlp) (4.66.5)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (1.14.0)
# Requirement already satisfied: networkx in c:\users\mitansh kanani\appdata\roaming\python\python312\site-packages (from torch>=1.0.0->stanfordnlp) (3.4.2)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (3.1.4)
# Requirement already satisfied: fsspec in c:\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (2024.6.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.0.0->stanfordnlp) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch>=1.0.0->stanfordnlp) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests->stanfordnlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->stanfordnlp) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->stanfordnlp) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mitansh kanani\appdata\roaming\python\python312\site-packages (from requests->stanfordnlp) (2024.8.30)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm->stanfordnlp) (0.4.6)
# Requirement already satisfied: conllu in c:\anaconda3\lib\site-packages (6.0.0)
# All packages installed successfully!

# %%
# Cell 2 - Imports and Setup (GOOD)
import nltk
import os
import random
from nltk import Tree
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk import word_tokenize, pos_tag
from collections import Counter
import matplotlib.pyplot as plt

# Download required NLTK data
print("Downloading NLTK resources...")
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
print("NLTK setup complete!")
# Out:
# Downloading NLTK resources...
# NLTK setup complete!
# [nltk_data] Downloading package punkt to C:\Users\Mitansh
# [nltk_data]     Kanani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Mitansh Kanani\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Mitansh
# [nltk_data]     Kanani\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\Mitansh
# [nltk_data]     Kanani\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# Cell 3 - Core Functions (NEEDS IMPROVEMENT)
def create_enhanced_gujarati_grammar():
    """
    Define an enhanced context-free grammar for Gujarati sentences
    """
    grammar = """
    S -> NP VP | VP | NP
    NP -> N | Det N | Adj N | NP PP | N NP
    VP -> V | V NP | V PP | Adv VP | V Adv
    PP -> P NP
    Det -> 'આ' | 'એ' | 'તે' | 'કોઈ' | 'દરેક' | 'બધા'
    N -> 'વનસ્પતિ' | 'પ્રાણી' | 'સજીવ' | 'કોષ' | 'જીવ' | 'પર્યાવરણ' | 'પ્રજનન' | 'પાણી' | 'હવા' | 'જમીન' | 'ઊર્જા' | 'ખોરાક'
    V -> 'છે' | 'કરે' | 'થાય' | 'રહે' | 'વધે' | 'જીવે' | 'ખાય' | 'પીએ' | 'જન્મે' | 'મરે'
    Adj -> 'નાનો' | 'મોટો' | 'લીલો' | 'સજીવ' | 'નિર્જીવ' | 'તાજું' | 'પ્રાથમિક'
    Adv -> 'ધીમે' | 'ઝડપથી' | 'સરળતાથી' | 'આસાનીથી'
    P -> 'માં' | 'પર' | 'થી' | 'સાથે' | 'માંથી' | 'ને' | 'ના'
    """
    return nltk.CFG.fromstring(grammar)

def parse_gujarati_sentence(sentence, grammar):
    """
    Parse a Gujarati sentence using the defined grammar
    """
    try:
        tokens = sentence.split()
        
        # Skip very long sentences
        if len(tokens) > 10:
            return None
            
        parser = nltk.ChartParser(grammar)
        trees = list(parser.parse(tokens))
        
        if trees:
            return trees[0]  # Return first parse tree
        else:
            return None
    except Exception as e:
        # print(f"   Parse error: {e}")  # Comment out for cleaner output
        return None

def visualize_parse_tree(tree, title="Parse Tree"):
    """
    Visualize the parse tree - simplified version
    """
    if tree:
        print(f"   Tree for: {title}")
        tree.pretty_print()
        print()  # Add spacing
        return tree
    else:
        print("   Could not parse the sentence")
        return None

# %%
# Cell 4 - Test with Sample Sentences (FIXED GRAMMAR)
# Enhanced Gujarati sentences from NCERT biology text
gujarati_sentences = [
    "સજીવ વનસ્પતિ છે",
    "પ્રાણી પર્યાવરણમાં જીવે છે", 
    "નાનો કોષ વધે છે",
    "સજીવ પ્રજનન કરે છે",
    "વનસ્પતિ પાણી છે",
    "કોષ મોટો છે",
    "પ્રાણી ખાય છે",
    "વનસ્પતિ હવા છે"
]

def create_comprehensive_gujarati_grammar():
    """
    Define a comprehensive context-free grammar for Gujarati sentences
    """
    grammar = """
    # Sentence patterns
    S -> NP VP | NP PP VP | VP | NP
    
    # Noun Phrases
    NP -> N | Det N | Adj N | NP PP | N NP | Adj NP | Det Adj N
    
    # Verb Phrases  
    VP -> V | V NP | V PP | V Adv | V NP PP | V NP Adv | Aux V | V Aux | V NP Aux
    VP -> V NP PP | V Adv NP | V NP NP
    
    # Prepositional Phrases
    PP -> P NP | P N | P Adj N
    
    # Words
    Det -> 'આ' | 'એ' | 'તે' | 'કોઈ' | 'દરેક' | 'બધા' | 'કેટલાક'
    N -> 'વનસ્પતિ' | 'પ્રાણી' | 'સજીવ' | 'કોષ' | 'જીવ' | 'પર્યાવરણ' | 'પ્રજનન' | 'પાણી' | 'હવા' | 'જમીન' | 'ઊર્જા' | 'ખોરાક' | 'પર્યાવરણમાં' | 'પાણીમાં'
    V -> 'છે' | 'કરે' | 'થાય' | 'રહે' | 'વધે' | 'જીવે' | 'ખાય' | 'પીએ' | 'જન્મે' | 'મરે' | 'જાય' | 'આવે'
    Adj -> 'નાનો' | 'મોટો' | 'લીલો' | 'સજીવ' | 'નિર્જીવ' | 'તાજું' | 'પ્રાથમિક' | 'મોટા' | 'નાના'
    Adv -> 'ધીમે' | 'ઝડપથી' | 'સરળતાથી' | 'આસાનીથી' | 'સહેલાઈથી'
    P -> 'માં' | 'પર' | 'થી' | 'સાથે' | 'માંથી' | 'ને' | 'ના' | 'ની'
    Aux -> 'છે' | 'હતું' | 'હતા'
    """
    return nltk.CFG.fromstring(grammar)

def debug_parse_attempt(sentence, grammar):
    """
    Debug why parsing fails for a sentence
    """
    print(f"   Debugging: '{sentence}'")
    words = sentence.split()
    print(f"   Words: {words}")
    
    # Check if all words are in grammar
    missing_words = []
    for word in words:
        found = False
        for production in grammar.productions():
            if word in production.rhs():
                found = True
                break
        if not found:
            missing_words.append(word)
    
    if missing_words:
        print(f"   ❌ Words not in grammar: {missing_words}")
    else:
        print(f"   ✅ All words found in grammar")
        
    # Try to parse with more detailed error info
    try:
        parser = nltk.ChartParser(grammar)
        trees = list(parser.parse(words))
        if trees:
            return trees[0]
        else:
            print(f"   ❌ No valid parse trees found")
            return None
    except Exception as e:
        print(f"   ❌ Parse error: {e}")
        return None

# Create comprehensive grammar and test parsing
grammar = create_comprehensive_gujarati_grammar()

print("Testing Comprehensive Parse Trees for Gujarati Sentences:")
print("=" * 65)

success_count = 0
for i, sentence in enumerate(gujarati_sentences, 1):
    print(f"\n{i}. Sentence: '{sentence}'")
    
    # First try normal parse
    tree = parse_gujarati_sentence(sentence, grammar)
    if tree:
        success_count += 1
        print("   ✓ Parse successful!")
        visualize_parse_tree(tree, f"'{sentence}'")
    else:
        print("   ✗ Parse failed - trying debug mode...")
        # Try with debug information
        tree = debug_parse_attempt(sentence, grammar)
        if tree:
            success_count += 1
            print("   ✓ Parse successful after debug!")
            visualize_parse_tree(tree, f"'{sentence}'")

print(f"\nSummary: {success_count}/{len(gujarati_sentences)} sentences parsed successfully ({success_count/len(gujarati_sentences):.1%})")

# Show grammar coverage
print(f"\nGrammar Coverage Analysis:")
print("=" * 40)
all_words = set()
for sentence in gujarati_sentences:
    all_words.update(sentence.split())

grammar_words = set()
for production in grammar.productions():
    for item in production.rhs():
        if isinstance(item, str) and not item.isupper():  # Terminal symbols
            grammar_words.add(item)

missing_words = all_words - grammar_words
print(f"Total unique words in sentences: {len(all_words)}")
print(f"Words covered by grammar: {len(grammar_words)}")
print(f"Missing words: {missing_words if missing_words else 'None!'}")
# Out:
# Testing Comprehensive Parse Trees for Gujarati Sentences:
# =================================================================
#
# 1. Sentence: 'સજીવ વનસ્પતિ છે'
#    ✓ Parse successful!
#    Tree for: 'સજીવ વનસ્પતિ છે'
#             S
#        _____|_____
#       NP          VP
#   ____|_____      |
# Adj         N     V
#  |          |     |
# સજીવ     વનસ્પતિ  છે
#
#
#
# 2. Sentence: 'પ્રાણી પર્યાવરણમાં જીવે છે'
#    ✓ Parse successful!
#    Tree for: 'પ્રાણી પર્યાવરણમાં જીવે છે'
#                         S
#          _______________|________
#         NP                       |
#    _____|_______                 |
#   |             NP               VP
#   |             |            ____|___
#   N             N           V       Aux
#   |             |           |        |
# પ્રાણી     પર્યાવરણમાં     જીવે      છે
#
#
#
# 3. Sentence: 'નાનો કોષ વધે છે'
#    ✓ Parse successful!
#    Tree for: 'નાનો કોષ વધે છે'
#               S
#        _______|_______
#       NP              VP
#   ____|___         ___|___
# Adj       N       V      Aux
#  |        |       |       |
# નાનો     કોષ     વધે      છે
#
#
#
# 4. Sentence: 'સજીવ પ્રજનન કરે છે'
#    ✓ Parse successful!
#    Tree for: 'સજીવ પ્રજનન કરે છે'
#                  S
#        __________|_______
#       NP                 VP
#   ____|____           ___|___
# Adj        N         V      Aux
#  |         |         |       |
# સજીવ     પ્રજનન     કરે      છે
#
#
#
# 5. Sentence: 'વનસ્પતિ પાણી છે'
#    ✓ Parse successful!
#    Tree for: 'વનસ્પતિ પાણી છે'
#              S
#           ___|____
#          NP       |
#     _____|___     |
#    |         NP   VP
#    |         |    |
#    N         N    V
#    |         |    |
# વનસ્પતિ     પાણી  છે
#
#
#
# 6. Sentence: 'કોષ મોટો છે'
#    ✗ Parse failed - trying debug mode...
#    Debugging: 'કોષ મોટો છે'
#    Words: ['કોષ', 'મોટો', 'છે']
#    ✅ All words found in grammar
#    ❌ No valid parse trees found
#
# 7. Sentence: 'પ્રાણી ખાય છે'
#    ✓ Parse successful!
#    Tree for: 'પ્રાણી ખાય છે'
#         S
#    _____|___
#   NP        VP
#   |      ___|___
#   N     V      Aux
#   |     |       |
# પ્રાણી ખાય      છે
#
#
#
# 8. Sentence: 'વનસ્પતિ હવા છે'
#    ✓ Parse successful!
#    Tree for: 'વનસ્પતિ હવા છે'
#              S
#           ___|___
#          NP      |
#     _____|___    |
#    |         NP  VP
#    |         |   |
#    N         N   V
#    |         |   |
# વનસ્પતિ     હવા  છે
#
#
#
# Summary: 7/8 sentences parsed successfully (87.5%)
#
# Grammar Coverage Analysis:
# ========================================
# Total unique words in sentences: 15
# Words covered by grammar: 56
# Missing words: None!

# %%
# Cell 5 - POS Analysis (GOOD)
def analyze_gujarati_pos_patterns(sentences):
    """
    Analyze POS patterns in Gujarati sentences (simulated)
    """
    print("Analyzing Gujarati Sentence Patterns:")
    print("=" * 40)
    
    pos_patterns = []
    
    for sentence in sentences:
        words = sentence.split()
        simulated_tags = []
        
        for j, word in enumerate(words):
            if word in ['છે', 'કરે', 'થાય', 'રહે', 'વધે', 'જીવે', 'ખાય', 'પીએ', 'જન્મે', 'મરે']:
                simulated_tags.append(('V', word))
            elif word in ['વનસ્પતિ', 'પ્રાણી', 'સજીવ', 'કોષ', 'જીવ', 'પર્યાવરણ', 'પ્રજનન', 'પાણી', 'હવા', 'જમીન', 'ઊર્જા', 'ખોરાક']:
                simulated_tags.append(('N', word))
            elif word in ['નાનો', 'મોટો', 'લીલો', 'સજીવ', 'નિર્જીવ', 'તાજું', 'પ્રાથમિક']:
                simulated_tags.append(('Adj', word))
            elif word in ['માં', 'પર', 'થી', 'સાથે', 'માંથી', 'ને', 'ના']:
                simulated_tags.append(('P', word))
            elif word in ['ધીમે', 'ઝડપથી', 'સરળતાથી', 'આસાનીથી']:
                simulated_tags.append(('Adv', word))
            else:
                simulated_tags.append(('?', word))
        
        pos_patterns.append(simulated_tags)
        print(f"\nSentence: {sentence}")
        print(f"Simulated POS: {simulated_tags}")
    
    return pos_patterns

# Analyze patterns in our sentences
pos_analysis = analyze_gujarati_pos_patterns(gujarati_sentences)
# Out:
# Analyzing Gujarati Sentence Patterns:
# ========================================
#
# Sentence: સજીવ વનસ્પતિ છે
# Simulated POS: [('N', 'સજીવ'), ('N', 'વનસ્પતિ'), ('V', 'છે')]
#
# Sentence: પ્રાણી પર્યાવરણમાં જીવે છે
# Simulated POS: [('N', 'પ્રાણી'), ('?', 'પર્યાવરણમાં'), ('V', 'જીવે'), ('V', 'છે')]
#
# Sentence: નાનો કોષ વધે છે
# Simulated POS: [('Adj', 'નાનો'), ('N', 'કોષ'), ('V', 'વધે'), ('V', 'છે')]
#
# Sentence: સજીવ પ્રજનન કરે છે
# Simulated POS: [('N', 'સજીવ'), ('N', 'પ્રજનન'), ('V', 'કરે'), ('V', 'છે')]
#
# Sentence: વનસ્પતિ પાણી છે
# Simulated POS: [('N', 'વનસ્પતિ'), ('N', 'પાણી'), ('V', 'છે')]
#
# Sentence: કોષ મોટો છે
# Simulated POS: [('N', 'કોષ'), ('Adj', 'મોટો'), ('V', 'છે')]
#
# Sentence: પ્રાણી ખાય છે
# Simulated POS: [('N', 'પ્રાણી'), ('V', 'ખાય'), ('V', 'છે')]
#
# Sentence: વનસ્પતિ હવા છે
# Simulated POS: [('N', 'વનસ્પતિ'), ('N', 'હવા'), ('V', 'છે')]

# %%
# Cell 6 - Corpus Analysis (FIXED PATHS)
import os
import random

def check_data_directory():
    """Check what files actually exist"""
    # Since your notebook is in 'notebooks' folder and data is in main project directory
    base_dir = '..'  # Go up one level from notebooks to main project directory
    absolute_base_path = os.path.abspath(base_dir)
    print(f"Checking directory: {absolute_base_path}")
    
    if os.path.exists(absolute_base_path):
        print("\nAvailable files in project directory:")
        for root, dirs, files in os.walk(absolute_base_path):
            # Only show top 2 levels to avoid too much output
            level = root.replace(absolute_base_path, '').count(os.sep)
            if level <= 2:  # Limit depth
                indent = ' ' * 2 * level
                print(f'{indent}{os.path.basename(root)}/')
                subindent = ' ' * 2 * (level + 1)
                for file in files[:10]:  # Limit files per directory
                    print(f'{subindent}{file}')
                if len(files) > 10:
                    print(f'{subindent}... and {len(files)-10} more files')
            if level > 2:
                break
    else:
        print(f"❌ Base data directory not found: {absolute_base_path}")

def generate_parse_trees_from_corpus(file_path, num_samples=5):
    """
    Generate parse trees from your processed Gujarati corpus
    """
    file_path = os.path.abspath(file_path)
    print(f"Looking for file: {file_path}")
    
    # Check if file exists
    if not os.path.exists(file_path):
        print(f"❌ File not found: {file_path}")
        check_data_directory()
        return 0.0
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            sentences = [line.strip() for line in f if line.strip()]
        
        print(f"Loaded {len(sentences)} sentences")
        
        if len(sentences) == 0:
            print("❌ File is empty")
            return 0.0
            
        # Select random samples for analysis
        sample_sentences = random.sample(sentences, min(num_samples, len(sentences)))
        
        grammar = create_enhanced_gujarati_grammar()
        
        print(f"\nGenerating Parse Trees for {len(sample_sentences)} sample sentences:")
        print("=" * 60)
        
        successful_parses = 0
        
        for i, sentence in enumerate(sample_sentences, 1):
            print(f"\n{i}. Sentence: '{sentence}'")
            
            # Simple sentence complexity check
            word_count = len(sentence.split())
            print(f"   Words: {word_count}")
            
            # Try to parse
            tree = parse_gujarati_sentence(sentence, grammar)
            if tree:
                successful_parses += 1
                print("   ✓ Parse successful")
                # For longer sentences, just show structure without full visualization
                if word_count <= 6:
                    visualize_parse_tree(tree, f"Sample {i}")
                else:
                    print("   (Sentence too long for detailed visualization)")
            else:
                print("   ✗ Parse failed")
        
        success_rate = successful_parses / len(sample_sentences) if sample_sentences else 0
        print(f"\nSummary: {successful_parses}/{len(sample_sentences)} sentences parsed successfully ({success_rate:.1%})")
        return success_rate
        
    except Exception as e:
        print(f"❌ Error reading file: {e}")
        return 0.0

# First check what files we have
check_data_directory()

print("\n" + "="*50)
print("ATTEMPTING TO LOAD CORPUS FILES:")
print("="*50)

# CORRECTED PATHS - since notebook is in 'notebooks' folder and data is in main directory
possible_paths = [
    '../data/next/class11_biology_prepro.txt',  # Go up to main dir, then into data/next
    './data/next/class11_biology_prepro.txt',   # Current directory (notebooks) doesn't have data
    'class11_biology_prepro.txt',               # Direct file in notebooks (unlikely)
    '../../data/next/class11_biology_prepro.txt' # Two levels up (might be wrong)
]

corpus_file = None
for path in possible_paths:
    absolute_path = os.path.abspath(path)
    if os.path.exists(absolute_path):
        corpus_file = path
        print(f"✅ Found file: {absolute_path}")
        break

if corpus_file:
    print(f"\n📁 Using corpus file: {corpus_file}")
    success_rate = generate_parse_trees_from_corpus(corpus_file, num_samples=3)
    print(f"\nOverall success rate: {success_rate:.1%}")
    
    # If success rate is 0%, it might be due to grammar complexity, not file reading
    if success_rate == 0:
        print("\n💡 Note: 0% success rate may be due to:")
        print("   - Complex sentence structures in the corpus")
        print("   - Limited grammar rules in our CFG")
        print("   - Vocabulary not covered in our grammar")
        print("\nLet's test with a simple sentence from the file to verify reading works...")
        
        # Test with first few sentences to see what we're working with
        try:
            with open(corpus_file, 'r', encoding='utf-8') as f:
                first_few = [line.strip() for line in f if line.strip()][:3]
            print("\nFirst 3 sentences from file:")
            for i, sent in enumerate(first_few, 1):
                print(f"  {i}. '{sent}' (words: {len(sent.split())})")
        except Exception as e:
            print(f"Error reading file for preview: {e}")
            
else:
    print("❌ No corpus files found. Using sample sentences instead.")
    # Use our sample sentences as fallback
    grammar = create_enhanced_gujarati_grammar()
    print("\nUsing built-in sample sentences:")
    success_count = 0
    for i, sentence in enumerate(gujarati_sentences[:3], 1):
        print(f"\n{i}. '{sentence}'")
        tree = parse_gujarati_sentence(sentence, grammar)
        if tree:
            success_count += 1
            visualize_parse_tree(tree, f"Sample {i}")
    print(f"\nSample sentences success: {success_count}/3 ({success_count/3:.1%})")
# Out:
# Checking directory: c:\Users\Mitansh Kanani\Desktop\college\sem 7\NLP\NLP_LAB_GYANGUJ
#
# Available files in project directory:
# NLP_LAB_GYANGUJ/
#   project_plan.md
#   README.md
#   requirements.txt
#   .git/
#     COMMIT_EDITMSG
#     config
#     description
#     FETCH_HEAD
#     HEAD
#     index
#     ORIG_HEAD
#     hooks/
#       applypatch-msg.sample
#       commit-msg.sample
#       fsmonitor-watchman.sample
#       post-update.sample
#       pre-applypatch.sample
#       pre-commit.sample
#       pre-merge-commit.sample
#       pre-push.sample
#       pre-rebase.sample
#       pre-receive.sample
#       ... and 4 more files
#     info/
#       exclude
#     logs/
#       HEAD
#
# ==================================================
# ATTEMPTING TO LOAD CORPUS FILES:
# ==================================================
# ✅ Found file: c:\Users\Mitansh Kanani\Desktop\college\sem 7\NLP\NLP_LAB_GYANGUJ\data\next\class11_biology_prepro.txt
#
# 📁 Using corpus file: ../data/next/class11_biology_prepro.txt
# Looking for file: c:\Users\Mitansh Kanani\Desktop\college\sem 7\NLP\NLP_LAB_GYANGUJ\data\next\class11_biology_prepro.txt
# Loaded 23 sentences
#
# Generating Parse Trees for 3 sample sentences:
# ============================================================
#
# 1. Sentence: 'ર-સમૂહ સાથે જોડાયેલ [ર-સમૂહ મિથાઇલ અથવા ઇથાઇલ ઉચ્ચ સંખ્યાવાળા સમૂહ કાર્બનથી કાર્બન] ઉદાહરણ તરીકે પામિટિક એસિડમાં કાર્બોક્સિલ સાથે કાર્બન જોવા મળે એરેકીડોનીક એસિડમાં કાર્બોક્સિલ કાર્બન સાથે કાર્બન પરમાણુ ફેટિએસિડ સંતૃપ્ત (હિબંધ વગર) અસંતૃપ્ત (એક તેથી વધુ દિબંધ) પ્રકારના હોઈ શકે બીજો સાદો લિપિડ ગ્લિસરોલ જે ટ્રાયહાઇડ્રોક્સિ પ્રોપેન ઘણા લિપિડમાં ફેટિ એસિડ તેમજ ગ્લિસરોલ બંને જોવા મળે ફેટિએસિડ ગ્લિસરોલ સાથે એસ્ટરીકૃત ત્યારે મોનોગ્લિસરાઇડ, ડાયગ્લિસરાઇડ તથા ટ્રાયગ્લિસરાઇડ હોઈ શકે તેઓના ગલનબિંદુના આધારે મેદ તેલ કહેવાય તેલનું ગલનબિંદુ અપેક્ષા કરતાં નીચું (તલનું તેલ) તેથી શિયાળામાં તેલ સ્વરૂપે શું બજારમાં મળતા ફેટની ઓળખાણ કરી શકો કેટલાક લિપિડમાં ફોસ્ફરસ ફોસ્કોરીકૃત કાર્બનિક સંયોજનો જોવા મળે ફોર્ફો લિપિડ જે કોપરસપટલમાં જોવા મળે લેસિથિન એનું દંષ્ટાંત કેટલીક પેશીઓમાં વિશિષ્ટ સ્વરૂપે ચેતાપેશીમાં વધારે જટિલ સંરચનાવાળા લિપિડ જોવા મળે જીવંત સજીવોમાં ઘણા કાર્બનિક સંયોજનો વિષમ ચક્રીય રીંગ સ્વરૂપે તેમાંથી કેટલાક નાઇટ્રોજન બેઝિસ એડેનીન, ગ્વાનીન, સાઇટોસીન, યુરેસિલ થાયમિન જયારે શર્કરા સાથે જોડાય ત્યારે તેને ન્યુક્લિઓસાઇડ કહે જો તેમાં ફોસ્ફેટ સમૂહ શર્કરા સાથે એસ્ટરબંધથી જોડાય તેને ન્યુક્લિઓટાઇડ કહે એડિનોસાઇન, ગ્વાનોસિન, થાયમિડિન, યુરિડિન સાઇટિડિન ન્યુક્લિઓસાઇડ એડેનિલિક એસિડ, થાયમેડિલિક એસિડ, ગ્વાનિલિક એસિડ, યુરિડિલિક એસિડ સાઈટિડિલિક એસિડ ન્યુક્લિઓટાઇડસ જેવા જ્યુક્સિઇક એસિડ માત્ર ન્યુક્લિઓટાઇડ ધરાવે ન્યુક્સિઇક એસિડ જેવા આનુવંશિક દ્રવ્ય તરીકે કામ જૈવઅણુઓ (પાં્ડ) લા,બા ૦ભ્બા લ૦્બા હા બ ી પ થિ લાબા બ બા બ યયસિ એલેની: સેરિઃ ન ર ગ્લ લે (ગ્લકોઝ) (રિબોઝ) પન પ એમિનો એસિડસ શર્કરાઓ (કાર્બોદિત) ડ્ર બા લા, ફટી એસિડ ત્રા-બા (પામિટિક એસિડ) બાબા ગ્લિસરોલ ટ્રાયગ્લિસરાઇડ પ ફેટી એસિડ છે) વાતા, હાઈ હા ફોસેલિપિડ(લેસીથીન) હ ણ હા ચરબી તેલ (લિપિડ્સ) એડેનીન પલી ર્ ભે ર એડેનીન ડ્ બા એડેનાઇન (પ્યુરિન) બા બ છડ એડેનોસાઇન બે યુરેસીલ બણ બા કિ એડેનિલિક એસિડ ક ભા બા યુરેસિલ (પિરિમિડિન) યુરિડિન નાઇટ્રોજન બેઇઝ ન્યુક્લિઓસાઇડ 'યુક્લિઓટાઇડ આકૃતિ જીવંત પેશીઓમાં જોવા મળતા ઓછો અણભાર ધરાવતા કાર્બનિક સંયોજનોનું રેખાંકન જીવવિજ્ઞાન પ્રાથમિક તેમજ દ્િતીયક ચયાપચયકો તલ પ૯) જીવંત સજીવોના અસંખ્ય નાના-મોટા સંયોજનોનું અલગીકરણ રસાયણ વિજ્ઞાનનો કુતૂહલ પ્રેરક દષ્ટિકોણ સજીવોની સંરચના નિર્ધારિત કરવામાં આવે શક્ય તેને સંશ્લેષિત કરવામાં આવે જો કોઈને જૈવઅણુઓની યાદી બનાવવી તેમાં હજારો કાર્બનિક રસાયણો જેવા એમિનો એસિડ, શર્કરા વગેરેનો સમાવેશ કરી શકાય કારણોથી તેને કોષ્ટક દર્શાવવામાં આવ્યા આપણે આવા જૈવઅણુઓને ચયાપચયકો કહીએ પ્રાણી પેશીઓમાં આવેલાં સંયોજનોની કક્ષાઓને આકૃતિ દર્શાવેલ તેને પ્રાથમિક ચયાપચયકો કોષ્ટક કેટલાક દ્રિતીયક ચયાપચયકો કહેવાય જયારે કોઈ વનસ્પતિ, ફૂગ સૂક્ષ્મજીવોનો કોષ વગેરેનું વિશ્લેષણ કરીએ તેમાં પ્રાથમિક ચયાપચયકો સિવાયના હજારો રસાયણો જેવા કે, આલ્કેલોઇડ, ફ્લેવોનોઇડ્સ, રબર, આવશ્યક તેલ, પ્રતિ જૈવિક દ્રવ્ય, રંગીન રંજકદ્રવ્ય, પરફ્યુમ, ગુંદર, મસાલા જોવા મળે તેને આપણે હિતીયક ચયાપચયકો કહીએ (કોષ્ટક પ્રાથમિક ચયાપચયકો જ્ઞાત કાર્ય દેહધાર્મિક કિયાઓમાં મહત્ત્વનો ભાગ ભજવે પરંતુ આપણે સમયે હિતીયક ચયાપચયકોની ભૂમિકા કાર્યો નથી જાણતા એમાંથી ઘણાં બધાં (જેવા રબર, ઔષધ, મસાલા, પરફ્યુમ રંજકદ્રવ્ય) મનુષ્યના કલ્યાણ ઉપયોગી કેટલાક ્િતીયક ચયાપચયકો આર્થિક અગત્યતા ધરાવે આગળના પ્રકરણો તેમજ વર્ષોમાં આનો વિસ્તૃત અભ્યાસ કરશો બૃહદ્ જૈવઅણુઓ એસિડ દ્રાવ્ય ભાગમાં સમાવિષ્ટ થતા રસાયણોની સામાન્ય વિશિષ્ટતા તેઓનો અણુભાર લગભગ ડાલ્ટન આસપાસ એસિડ અદ્રાવ્ય જૂથમાં માત્ર ચાર પ્રકારના કાર્બનિક સંયોજનો જેવા પ્રોટીન, ન્યુક્લિઇક એસિડ, પોલિસેકેરાઇડ્સ તેમજ લિપિડ જોવા મળે લિપિડના અપવાદને બાદ કરતા શ્રેણીના સંયોજનોનો અણુભાર હજાર ડાલ્ટન તેનાંથી વધુ કારણથી જૈવઅણુઓ એટલે સજીવોમાં જોવા મળતા રસાયણિક સંયોજનો બે પ્રકારનાં જેઓનો અણુભાર હજાર ડાલ્ટનથી ઓછો તેને સામાન્ય રીતે સૂક્ષ્મઅણુ સૂહ્મ જૈવઅણુ કહેવાય જયારે જે એસિડ અદ્રાવ્ય જૂથમાં જોવા મળે તેઓને બૃહદ્ અણુ અથવા બૃહદ્ જૈવઅણુ કહેવામાં આવે લિપિડના અપવાદ સાથે અદ્રાવ્ય જૂથમાં જોવા મળતા અણુઓ પોલીમર પદાર્થો શા લિપિડ જેનો અણુભાર નથી એસિડ અદ્રાવ્ય જૂથમાં અર્થાત્ બૃહદ્ અણુઓ તરીકે સમાવેશ થાય વાસ્તવમાં લિપિડ્સ ઓછો અણુભાર ધરાવતાં સંયોજનો સ્વરૂપમાં જોવા મળતા નથી પરંતુ કોપરસપટલ બીજા પટલોમાં જોવા મળે જયારે આપણે પેશીઓને વાટીએ ત્યારે કોષીય સંરચના વિઘટન પામે કોષરસપટલ અન્ય બીજા પટલોનાં ટુકડાં થઈ જાય તથા જૈવઅણુઓ પુટિકા બને જે પાણીમાં અદ્રાવ્ય કારણસર પટલો પુટેકા સ્વરૂપે એસિડ અદ્રાવ્ય જૂથમાં અલગ થઈ જાય છે, જે બૃહદ્ આણ્વીય અંશનો ભાગ સાચા ...
#    Words: 2590
#    ✗ Parse failed
#
# 2. Sentence: 'કહે કેટલ/ કાઈન ૪રમ/ણુઓ ર૬ ઉચ્ચ કક્ષાની વનસ્પતિઓમાં પ્રકાશસંશ્લેષણ ()/૯ડાંડ [હા ણિંથ॥) વૈજ્ઞાનિકોએ જાણવાનો પ્રયત્ત કર્યો શું બધી વનસ્પતિઓ સ્થાપન કર્યા પછી પહેલી નીપજ પછી અન્ય વનસ્પતિઓમાં કોઈ બીજી નીપજનું નિર્માણ થતું હશે અન્ય વનસ્પતિ સમૂહોમાં વ્યાપક સંશોધન કરવામાં આવ્યું જ્યાં )તું સ્થાપન થયા પછી પહેલી સ્થાયી નીપજ પુન: કાર્બનિક એસિડ હતો, જેમાં કાર્બનના ચાર પરમાણુ હતા એસિડ ઓક્ઝેલો એસિટિક એસિડ અથવા તરીકે ઓળખવામાં આવ્યો ત્યાર પછીથી પ્રકાશસંશ્લેષણ દરમિયાન ;ના સ્વાંગીકરણ પરિપાચન મુખ્ય બે પ્રકારે થાય એમ કહી શકીએ જે વનસ્પતિઓમાં )નું સ્થાપન થયા પછી પહેલી નીપજ હતી તેમને પરિપથ જેમની પ્રથમ નીપજ એસિડ હતી તેને પરિપથ કહે બંને સમૂહોની વનસ્પતિઓમાં અન્ય આનુષંગિક લાક્ષણિકતાઓ છે, જેની ચર્ચા આપણે પછી કરીશું )નો પ્રાથમિક ગ્રાહક આવો, આપણે આપણી જાતને પ્રશ્ન પૂછીએ, જેવી રીતે વૈજ્ઞાનિકો પૂછાયેલો હતો જેઓ અંધકાર પ્રક્રિયાને સમજવા સંઘર્ષ કરી રહ્યા હતા ગ્રહ (સ્થ(થ૪) ડયઈ બદ, કાઈન ર૫/તર કરજ મટે જવર અણુ કાઈન કેટલ જરમહણું હશે ખૂબ અનપેક્ષિત રીતનો અભ્યાસ દર્શાવે ગ્રહણ કરનાર અણુ પાંચ કાર્બનયુક્ત કિટોઝ શર્કરા હતી રિબ્યુલોઝ બાયફોસ્ફેટ હતી શું તમામ કોઈએ અઇ સંભવ જિશે વિચ હતું ચિંતા ન કરો વૈજ્ઞાનિકોએ તારણ સુધી પહોંચવા ઘણો સમય લીધો હતો તેમણે કોઈ નિર્ણય પહોંચતા પહેલા ઘણા પ્રયોગો કર્યા હતા તેઓ એમ માનતા હતા પહેલી નીપજ એસિડ હોય, પ્રાથમિક ગ્રાહક કાર્બનવાળો સંયોજન હશે તેઓએ કાર્બનવાળો પદાર્થ સંયોજન [૨ના સંશોધન પહેલા કાર્બનવાળા સંયોજનને ઓળખવા માટેનો પ્રયત્ન થણાં વર્ષો સુધી કર્યો કેલ્વિનચક્ર કૅલ્વિન તેમના સાથીદારોએ સંપૂર્ણ પરિપથ વિશેનું સંશોધન કરીને દર્શાવ્યું પરિપથ ચક્રીય કમમાં સંચાલિત છે; જેમાં [૨નું પુનઃ નિર્માણ થાય આવો, જોઈએ કૅલ્વિનચક્રનો પરિપથ કેવી રીતે સંચાલિત થાય શર્કરા ક્યાં સંશ્લેષણ પામે છે? આવો, સ્પષ્ટ રીતે સમજી લઈએ કૅલ્વિનચકર બધી પ્રકાશસંશ્લેષિત વનસ્પતિઓમાં થાય તેનાથી કોઈ ફેર પડતો નથી અથવા પરિપથ (અથવા કોઈ અન્ય પરિપથ) ધરાવતી (આકૃતિ કૅલ્વિનચક્રને સરળતાથી સમજવા તેનું કાર્બોક્સિલેશન, રિડક્શન પુનઃસર્જન (રિટલાણાળ) એમ ત્રણ તબક્કામાં વર્ણન કરાય કાર્બોક્સીલેશતન ઃ સ્થાપનની પ્રક્રિયા જેમાં સ્થાયી કાર્બનિક મધ્યસ્થી પદાર્થ બને કૅલ્વિનચક્રમાં કાર્બોક્સિલેશન અતિ નિર્ણાયક તબક્કો છે, જેમાં ૨૫ના કાર્બાક્સિલેશન )નો ઉપયોગ થાય પ્રક્રિયા ઉત્સેચક કા્બોક્સિલેઝ ઉત્તેજિત થાય છે, જેના પરિણામ સ્વરૂપે બે અણુઓ બને ઉપરાંત ઉત્સેચક ઓક્સિજીનેશન કરવાની ક્ષમતા ધરાવે આમ, વધારે યોગ્ય હશે આપણે ઉત્સેચકને કાર્બોક્સિલેઝ ઓક્સિજીનેઝ અથવા રુબિસ્કો તરીકે ઓળખીશું જીવવિજ્ઞાન વાતાવરણ કાર્બોક્સિલેશન પ પુનઃસર્જન ભી રિડક્શન પરિ દ સુક્રોઝ, સ્ટાર્ચ આકૃતિ કેલ્વિનચકરને ત્રણ ભાગોમાં વહેંચી શકાય કાર્બોક્સીલેશન, જે દરમિયાન રિબ્યુલોઝ બાય ફોસ્ફેટની સાથે જોડાય રિડક્શન, જે દરમિયાન કાર્બોદિતનું નિર્માણ પ્રકાશ રાસાયણિક પ્રક્રિયાથી બનેલા પાના વપરાશથી થાય પુનઃસર્જન, જે દરમિયાન ગ્રાહી રિબ્યુલોઝ બાયફોસ્ફેટનું પુતતઃનિર્માણ થાય તથા ચક્ર સતત ચાલતું રહે રિડક્શન ગ્લુકોઝનું નિર્માણ કરતી પ્રક્રિયાઓની શુંખલા તબક્કામાં પ્રત્યેક ;અણુનું સ્થાપન અણુઓનો ઉપયોગ કોસ્કોરાયલેશન ,ગના બે અણુઓનો ઉપયોગ રિડક્શન થાય પરિપથમાં ગ્લુકોઝનો અણુ બનવા )ના અણુઓનું સ્થાપન ચકનું ચક્રીયકરણ વખત જરૂરી રિજનરેશન (પુનઃસર્જન) જો ચક્રને અવરોધ ખલેલ વિના સતત ચાલતુ રહેવા ગ્રાહી અણુ પુનઃસર્જન થવું જરૂરી પુનઃસર્જનના તબક્કામાં [ના નિર્માણ હેતુ કોસ્ફોરાયલેશન &ની આવશ્યકતા ઉચ્ચ કક્ષાની વનસ્પતિઓમાં પ્રકાશસંશ્લેષણ ()/૯ડાંડ [હા ણિંથ॥) એટલા માટે, કૅલ્વિનચક્રમાં ;ના પ્રત્યેક અણુનો પ્રવેશ અણુ ૫ના બે અણુઓની આવશ્યકતા અંધકાર પ્રક્રિયામાં વપરાતા અણુની સંખ્યાના તફાવતને પહોંચી વળવા ચક્રીય ફોટો ફૉસ્ફોરાયલેશન થાય ગ્લુકોઝના અણુના નિર્માણ ચક્રને વખત ચક્રીયકરણની આવશ્યકતા ગણતરી કરો કેલ્વિ? પરિજક/ માધ્યમ ગ્લુકોઝ અણુ? રચ૪/ કેટલ/ અજુઓ જરૂર તમને વાતને કદાચ સમજવામાં મદદ મળશે કૅલ્વિનચ્માં શું અંદર પ્રવેશે શું બહાર નીકળે પરિપથ અગાઉ જણાવ્યા મુજબ, ઉષ્ણ કટિબંધીય વિસ્તારમાં અનુકૂલન પામેલ વનસ્પતિઓ પરિપથ ધરાવે વનસ્પતિઓમાં સ્થાપન થવાથી પહેલી સ્થાયી નીપજ તરીકે ઓક્ઝેલો એસિટિક એસિડનું નિર્માણ થાય છતાં આના મુખ્ય જૈવસંશ્લેપણ પરિપથ તરીકે પરિપથ અથવા કૅલ્વિનચક્રનો ઉપયોગ ત્યારે વનસ્પતિઓ, વનસ્પતિઓ કરતા કઈ રીતે જુદી પડે પ્રશ્ન જે પૂછી શકો વનસ્પતિઓ વિશિષ્ટ તેઓ તેમના પર્ણોમાં વિશિષ્ટ પ્રકારની અંતઃસ્થ રચના ધરાવે જે ઊંચા તાપમાનને સહન કરી શકે તેઓ પ્રકાશની વધુ તીવ્રતાની સામે પ્રતિક્રિયા દર્શાવે તેમાં પ્રકાશશ્વસન કહેવાતી પ્રક્રિયાનો અભાવ જોવા મળે છે, તેઓમાં જૈવભારની ખૂબ ઊંચી ઉત્પાદકતા આવો, તેઓને એક-એક કરીને સમજીએ પર્ણોનો ...
#    Words: 872
#    ✗ Parse failed
#
# 3. Sentence: ''ા૨ડનો સમૂહ વૃદ્ધિ પ્રેરક ક્રિયાવિધિ સાથે સંકળાયેલા છે, જેમ કોષ વિભાજન, કોષ વિસ્તરણ, નિર્માણની રીત, આવર્તનીય વૃદ્ધિ, પુષ્પસર્જન, ફળ નિર્માણ બીજ નિર્માણ વગેરે તેમને વનસ્પતિ વૃદ્ધિ પ્રેરકો કહે ઓક્ઝિન્સ, જીબરેલીન્સ સાયટોકાઇનીન્સ બીજા સમહના વૃદ્ધિ નિયામકો ઘા રુઝવવાની ક્રિયા તથા જૈવિક અજૈવિક તાણ સામે પ્રતિક્રિયા આપવામાં મહત્ત્વનો ભાગ ભજવે તેઓ વૃદ્ધિ અવરોધક કિયાવિધિ સાથે સંકળાયેલ જેવી સુષુપ્તા પતન એબ્સિસિક એસિડ વનસ્પતિ વૃદ્ધિ નિયામકના સમૂડમાં સમાયેલા વાયુમય થિલિન) કોઈ સમૂહની સાથે બંધ બેસે પરંતુ વૃદ્ધિની પ્રક્રિયાને વ્યાપક રીતે અવરોધે એટલે વૃદ્ધિ અવરોધક વનસ્પતિ વૃદ્ધિ નિયામકોનું સંશોધન રસપ્રદ રીતે [૨ડનાં પાંચ મુખ્ય સમૂહોમાંના પ્રત્યેકનું સંશોધન આકસ્મિક સંયોગ ધરાવે આની શરૂઆત ચાર્લ્સ ન ન ગા) હુ ડાર્વિન તેમના પુત્ર ફાન્સીસ ડાર્વિનના અવલોકનથી થઈ જયારે તેઓએ નિરીક્ષણ કર્યું કેનેરી ઊ)ના ભ્રણાગ્રચોલ પ્રકાશના સોત તરફના વિકાસની એકધારી પ્રતિક્રિયા દર્શાવે એટલે પ્રકાશ ઉદ્ગમની તરફ વૃદ્ધિ (પ્રકાશનું વર્તન) પ્રયોગોની થે છ હ વ શ્રેણીબદ્ધ ક્રિયાઓ દર્શાવ્યા પછી, નિર્ણય આવ્યો ભ્રણાગ્રચોલની ટોચ વાહક પ્રેરણનું સ્થાન બ્રણાગ્રચોલના આકૃતિ ભણાગ્રચોલનો અગ્રસ્થ ભાગ જે ઓક્ઝિનનો સોત સેપૂર્ણ વળાંક માટેનું કારણ (આકૃતિ ઓક્ઝિનનું તેનું નિદર્શન દર્શાવતો ઉપયોગી પ્રયોગ તીર- ઝંલગીકરણ એફ ડબલ્યુ વેન્ટ જવના બીજાંકુરણના પ્રકાશની દિશાનું નિર્દેશન ભ્રણાગ્રચોલના અગ્રસ્થ ભાગ (ટોચ )માંથી કરવામાં આવ્યું હતું વન્તસ્પતિ વૃદ્ધિ વિકાસ થત કાને' મૂર્ખ બીજાંકુરણ) ડાંગરના છોડ(બીજાંકુરિત રોપા)નો રોગ જે રોગકારક ફૂગ જીબરેલા ફુજીકુરોઇ થાય કુરોસાવા જાપાનીઝ વૈજ્ઞાનિકે તંદુરસ્ત ડાંગરના બીજાંકુરણ છોડમાં રોગના લક્ષણો જોયા જેઓને ફૂગના જંતુમુક્ત ગાળણ (]ૃાટ)ની સારવાર આપેલ હતી સક્રિય પદાર્થની ઓળખ ત્યાર બાદ જીબરેલિક એસિડ તરીકે થઈ સ્કૂગ તેમના સાથીદારોએ નિરીક્ષણ કર્યું તમાકુના પ્રકાંડના આંતરગાંઠના ભાગોમાંથી કેલસ (અવિભેદિત કોષોનો સમૂઠ) ત્યારે મેળવી શકાય જયારે ઓક્ઝિન ઉપરાંત વાહક પેશીઓનાં સત્વ, યીસ્ટનું સત્વ, નારિયેળનું દ્ધ પૂરક સ્વરૂપે માધ્યમમાં આપવામાં આવ્યું મિલર તેના સાથીદારો પછીથી સાઇટોકાઇનેસીસ પ્રેરક સક્રિય પદાર્થની ઓળખ કરી તેનું સ્ફટિકીકરણ કરી તેઓએ તેને કાઇનેટીન નામ આપ્યું મધ્યમાં ત્રણ સ્વતંત્ર સંશોધનોએ ત્રણ અલગ અલગ પ્રકારના અવરોધકોનું શુદ્ધીકરણ તેમજ રાસાયણિક લાક્ષણિકરણ નોંધ્યું તેઓના અવરોધક-, એબ્સિસિન તેમજ ડોર્મિન નામ હતા ત્યારબાદ ત્રણેય પદાર્થો રાસાયણિક રીતે એકસરખા સાબિત થયા તેમનું નામકરણ એબ્સિસિક એસિડના રૂપમાં કરવામાં આવ્યું કઝિન્્સે નોંધ્યું પાકેલા સંતરામાંથી મુક્ત થતો બાષ્પશીલ પદાર્થ તેની નજીકમાં રાખેલા અપરિપક્વ કાચા કેળાંને ઝડપથી પકવી નાંખે ત્યારબાદ બાષ્પશીલ પદાર્થને ઇથિલિન તરીકે ઓળખવામાં આવ્યો હતો જે વાયુમય આવો, આપણે પાંચ પ્રકારના [૨ની દેહધાર્મિક અસરનો અભ્યાસ પછીના વિભાગમાં કરીએ વનસ્પતિ વૃદ્ધિ નિયામકોની દેહધાર્મિક અસરો વિ્િલ્લ(ડ તિ ઓક્ઝિન્સ ઓક્ઝિન (ગ્રીક શબ્દ ટાં એટલે વૃદ્ધિ પામવું થાય છે)ને સૌપ્રથમ મનુષ્યના મૂત્રમાંથી અલગીકરણ કરવામાં આવ્યું ઓક્ઝિન્સ શબ્દનો ઇન્ડોલ--એસિટિક એસિડ કેટલાક વૃદ્ધિ નિયમના ગુણધર્મો ધરાવતા અન્ય કુદરતી તેમજ કૃત્રિમ (સંશ્લેષિત) સંયોજનો ઉપયોગ કરાય તેઓ સામાન્ય રીતે પ્રકાંડ તેમજ મૂળની વૃદ્ધિ પામતી ટોચના ભાગે ઉદ્દભવે ત્યાંથી તેમનું વહન કાર્ય સ્થાને થાય ઓક્ઝિન જેવાં તેમજ ઇન્ડોલ બ્યુટેરિક એસિડ વનસ્પતિઓમાંથી અલગ કરી મેળવી શકાય (નેપ્ફથેલીન એસિટિક એસિડ) (,-ડાયક્લોરો ફિનોક્સી એસિટિક એસિડ) કૃત્રિમ સંશ્લેપિત ઓક્ઝિન્સ ઓ્ઝિન્સની વ્યાપક રીતે કૃપિવિદ્યા બાગાયત વિદ્યાના અભ્યાસમાં ઉપયોગિતા તેઓ પ્રકાંડના કાપેલા ભાગો કલમોમાં મૂળ નિર્માણ મદદરૂપ થાય જે વનસ્પતિનાં પ્રસર્જન વ્યાપક રીતે ઉપયોગમાં લેવાય ઓક્ઝિન્સ પુષ્પસર્જન પ્રેરે છે, ઉદા વનસ્પતિઓના પર્ણો તેમજ ફળોને વહેલા ખરી જતાં અટકાવે પરંતુ જીર્ણ તેમજ પરિપક્વ પર્ણો ફળોના પતનને પ્રેરે મોટા ભાગની ઉચ્ચ કક્ષાની વનસ્પતિઓમાં અગ્ર કલિકા પાર્શ્વ (કક્ષ) કલિકાઓની વૃદ્ધિને અવરોધે ઘટનાને અગ્રીય પ્રભાવિતા પ્રરોહના અગ્રસ્થ ભાગ (ટોચ)ને કાપીને દૂર કરવાથી (શિરચ્છે દન- તંણ્લયાપા) સામાન્યત: પાર્શ્વ કલિકાઓની વૃદ્ધિ પ્રેરાય (જુઓ આકૃતિ બાબતનો વ્યાપક ઉપયોગ ચાના બગીચામાં રોપાનું ભૂમિમાં આરોપણ કરતી વખતે તેમજ વાડ બનાવવામાં ઉપયોગી બને શું જણાવી શકો, કેમ જીવવિજ્ઞાન ઓક્ઝિન્સ અફલિત ફળ વિકાસને પ્રેરે જેમ ટામેટામાં તેનો વ્યાપક રીતે તૃણનાશક તરીકે ઉપયોગ થાય બહોળા પ્રમાણમાં હિદળી નીંદણનો નાશ છે; પરંતુ પરિપક્વ એકદળી વનસ્પતિઓ તેની અસર થતી નથી તેનો ઉપયોગ માળીઓ દારા નીંદણવિહીન લોન(ઘાસ)ને વૈયાર કરવામાં થાય ઓક્ઝિન્સ જલવાહકતા વિભેદનનું નિયંત્રણ કરવામાં કોષવિભાજનમાં મદદરૂપ  ...
#    Words: 1223
#    ✗ Parse failed
#
# Summary: 0/3 sentences parsed successfully (0.0%)
#
# Overall success rate: 0.0%
#
# 💡 Note: 0% success rate may be due to:
#    - Complex sentence structures in the corpus
#    - Limited grammar rules in our CFG
#    - Vocabulary not covered in our grammar
#
# Let's test with a simple sentence from the file to verify reading works...
#
# First 3 sentences from file:
#   1. 'જીવવિજ્ઞાન ધોરણ ઉઠે પ્રતિજ્ઞાપત્ર ભારત મારો દેશ બધાં ભારતીયો મારા ભાઈબહેન મારા દેશને ચાહું છું તેના સમૃદ્ધ વૈવિધ્યપૂર્ણ વારસાનો મને ગર્વ સદાય તેને લાયક બનવા પ્રયત્ત કરીશ મારાં માતાપિતા, શિક્ષકો વડીલો પ્રત્યે આદર રાખીશ અન્તે દરેક જણ સાથે સભ્યતાથી વર્તશ મારા દેશ અનને દેશબાંધવોને મારી નિષ્ઠા અર્પુ છું ઈ ગ કલ્યાણ અનને સમૃદ્ધિમાં મારું સુખ રહ્યું વ્નકનરળ પક રાષ્ટ્રીય રૉલ્ષિય? ડાનુસંઘાન ગ્ર પ્રરિક્ષળ પરિષટ્ ગુજરાત રાજય શાળા પાઠયપુસ્તક મંડળ વિદ્યાયન' સેક્ટર ગાંધીનગર- અનુવાદ ડૉ આચાર્ય શ્રી નીતિન ડી દવે શ્રી મેહુલ એસ પટેલ સમીક્ષા ડૉ મોદી શ્રી જયસુખભાઈ બી હરમાણી શ્રી પરેશ એમ પરીખ શ્રીમતી ભાર્ગવી જી વાનખેડે શ્રીનિમેષ દરજી શ્રીપ્રશાંત જી પંચલ ભાષાશુદ્ધિ શ્રી નીતિન બી આચાર્ય અનુવાદ-પરામર્શન (સંવર્ધિત આવૃત્તિ) ડૉ આચાર્ય શ્રી નીતિન ડી દવે શ્રી જયસુખભાઈ બી હરમાણી શ્રી અવિનાશ ભટ્ટ સંયોજન ડૉ પટેલ (વિષય-સંયોજક ભૌતિકવિજ્ઞાન) નિર્માણ-સંયોજન ડૉ પરમાર (નાયબ નિયામક શૈક્ષણિક) મુદ્રણ-આયોજન શ્રી મનીષ એચ બધેકા (નાયબ નિયામક ઉત્પાદન) વિતરણ-આયોજન શ્રી હર્ષદ એચ ચૌધરી (નાયબ નિયામક વહીવટ વિતરણ) પ્રસ્તાવના રાષ્ટ્રીય સ્તરે સમાન અભ્યાસક્રમ રાખવાની સરકારશ્રીની નીતિના અનુસંધાને ગુજરાત સરકાર તથા ગુજરાત માધ્યમિક ઉચ્ચતર માધ્યમિક શિક્ષણ બોર્ડ તા ઠરાવ ક્રમાંક શાળા કક્ષાએ પારના પાઠ્યપુસ્તકોનો સીધો અમલ કરવાનો નિર્ણય કરવામાં આવ્યો તેને અનુલક્ષીને નવી દિલ્હી દારા પ્રકાશિત ધોરણ પના જીવવિજ્ઞાન વિષયના પાઠ્યપુસ્તકનો ગુજરાતીમાં અનુવાદ કરીને વર્ષ અમલ કરવામાં આવ્યો હતો પાઠયપુસ્તકનો અનુવાદ થયો સમયે તેની સમીક્ષા નિષ્ણાત પ્રાધ્યાપકો શિક્ષકો પાસે કરાવવામાં આવી હતી સમીક્ષકોનાં સૂચનો અનુસાર હસ્તપ્રતમાં યોગ્ય સુધારા-વધારા કર્યા પછી પાઠ્યપુસ્તક પ્રસિદ્ધ કરતાં પહેલાં પાક્યપુસ્તકની મંજૂરી સ્ટેટ લેવલની કમિટીની રચના કરવામાં આવી હતી કમિટીની સાથે ા૨ના પ્રતિનિધિ તરીકે ભોપાલથી ઉપસ્થિત રહેલા નિષ્ણાતોની સાથે દ્રિદિવસીય કાર્યશિબિરનું આયોજન કરવામાં આવ્યું મકવાણા ભોપાલ), ડૉ કલ્પના મસી ભોપાલ), ડો હર્ડીકર, શ્રી નીતિન ડી દવે, શ્રીમતી સોનલ ટી ભાટિયા શ્રી પ્રશાંત મહેતાએ ઉપસ્થિત રહી પોતાનાં કીમતી સૂચનો માર્ગદર્શન પૂરાં પાડયાં હતાં વર્ષ નવી દિલ્હીએ પોતાનાં પાઠ્યપુસ્તકની સંવર્ધિત આવૃત્તિ તૈયાર કરી અનુસંધાને ગુજરાત માધ્યમિક ઉચ્ચતર માધ્યમિક મઉમશબ,સંશોધન//-, તા આપવામાં આવેલી સૂચના અનુસાર ગુજરાતી અનુવાદની સંવર્ધિત આવૃત્તિ તૈયાર કરીને વિદ્યાર્થીઓ સમક્ષ મૂકતાં ગુજરાત રાજય શાળા પાઠ્યપુસ્તક મંડળ આનંદ અનુભવે પ્રસ્તુત પાઠ્યપુસ્તકને રસપ્રદ, ઉપયોગી ક્ષતિરહિત બનાવવા મંડળ પૂરતી કાળજી લેવામાં આવી છે, તેમ છતાં શિક્ષણમાં રસ ધરાવનાર વ્યક્તિઓ પાસેથી ગુણવત્તા વધારે તેવાં સૂચનો આવકાર્ય પ૫૨, નવી દિલ્હીના સહકાર બદલ તેમના આભારી શિક્ષણ બોર્ડ, ગાંધીનગરના પત્રક્રમાંક ડૉ વિનોદ રામચંદ્ર રાવ કાર્યવાહક પ્રમુખ ગાંધીનગર વિનયગિરિ ગોસાઈ ત્તિયામક તા પ્રથમ આવૃત્તિ પુનઃમુદ્રણ સંવર્ધિત આવૃત્તિ પુનઃમુદ્રણ પ્રકાશક ગુજરાત રાજ્ય શાળા પાઠ્યપુસ્તક મંડળ, 'વિધયાયન', સેક્ટર ગાંધીનગર વતી વિનયગિરિ ગોસાઈ, નિયામક મુદ્રક ડટ હા રાં ૦૫ડાંવટ થ ઉંટ) પા ધટ પ ત થવ થળ તંથ૪૦૦)ટ્ ાંડ ડાંકાાંઝિ થ હટ) થલ ઘાણ તાંડ૦૦॥ ડળ) લીંધિટાટાઈ $પટટા લાડ પાં! ઘડ પિ ટ લાં્ટલાંા વૉાત-૦૦૦ત ડાણ ધટ પાળા તંથ)થાતંડ ડા) ધળા પ લદટ વાવતા ીથટા ધણા શલાંપાંધલડ શ્વ લૃપ૦ છાપા બંધાવા છુલાટાલાટ પધ ઢા થ્॥ હાથા) પ૪૦ [)ટા૦ટં હતા ાંબ)થ શ પિટ પાણા છ તથા) વ્યય ાંપટલ વળ લાટ લંહાટત પ તંણાઢા ટર્ષિટલાંપટ [ટપ્ંદ પણાલ ડટ હા શ લ લંણ્ડાંકાટ તાડ પાતંટા પડા પહાપા શ થા તીંદિયા થા ખી હાય્યાટા થા હપાથ ટ્ ાંપાંપ ત લીંડ૦૫ડડં ડાળ દલાંપં ટડ પાળા થ))ંથાટડ પ૦ તં૦ટ તં પંડ તપંડા/ ઢાંલ૦૦ ઈપાંપલાડાં ખિટાંધ, ટા છપાવા ૪૦ઈદ ડહપહાળાં તહાઝા થા છાપાં ધા [થા છિ ૫૯ઝાલ વલ છલ પ૪/ છહાા૫ડાં [હાપ૯લ પડ તોપ પા ડ૦૫'૦૯ડ, રાહાથાં થલ પે/ થા' [૦દાંથ)/ હાટ પ॥ાંળાળોં પઈ ાંધથલ થલ પણા ધટ (થા પળ પાં! થલ ડ)ડાણા થલ વૃપય)/ પ૨ ૦૦ભ થલ લાઈ પાલણાથાંદટ પિણ [ંડાંા થલ !હીછ પિદથ /ટ૮૮૭/૭ટ/ થલ શો દ પાળા રે ભં તહ, ટલ ડા તંલ, પાળા વાં લા ઝાળાડાંડ૯ડ હતંઘ્લાર્ડ વાલે લાલા છત હાહાહ લંડલ, લી પિર લલ્લા વા [હાર્ડ હતં) તંા[હત પહર ૧૯૦ડડ લંટાડડ૯ડ દલા ૦૦ડાંતલા'દા) હઝલાાંડ૯ બ લાગા ડાયા હબલ લઘલંલ્લ ડલ થાહ્ાડ ડા લંદડડ ડૉ લલલત લા લંટડડ ધાંઝુંલ્લ હટડાં ડા લંલા ૯હ૯હા હાડ થલ હા ૯થા(્્ હોલા છાલ [ઝ૯ડલા ૯લી થ થલા પાલા; પંપા છઃ પ॥ંપલાડાં; ધાઈા પાતા, ઈપાંપણકાંછ' ખલ, ૪૦દ૧૯ડપ૪થા' લ ઈ૪૦ડા)/ પ પીંછા, હિરા છ થ ડ પલે)લાલ)/થ, ૬ડ [લ્લા ૪લ)/થાથઝથ ઈપટાડાં/ થલ છા ળ૯ા'ડાં) રિલ દાંડ પડ ઈલંડલાલ)/થ પલથ થલ છાટ) /લ૪૯ડ લાંપાંલપથ થલ ઝા પથર્લીડથ [૧૯૯ડ; ડાથાંથ]થ ડા લથા'લં પહ થલ પપ થલ થલ થટાંદ પડલ ડા છી લ ણ  ...
#   2. 'ધરાવે ફૂગની કોષદીવાલ કાઇટીન પોલીસેકેરાઇડસ([ં)/ડથવણીથાઈંવણ્ડ)થી સંઘટીત થયેલી જેને ફંગસ સેલ્યુલોઝ કહે મોટા ભાગની ફૂગ વિષમપોષી પોષણ મૃત આધારકો(વંણ્લતં )માંથી દ્રાવ્ય કાર્બનિક પદાર્થોનું શોષણ છે, આથી તેને મૃતોપજીવી ફૂગ કહે કેટલીક ફૂગ જીવંત વનસ્પતિઓ જીવંત પ્રાણીઓ આધાર રાખીને જીવન ગુજારે જેને પરોપજીવી ફૂગ કહે તેઓ સહજીવીઓ તરીકે જીવન જીવે લીલ સાથેનો તેનો સહવાસ સહજીવન લાઇકેન્સ તરીકે ઉચ્ચ કક્ષાની વનસ્પતિઓના મૂળ સાથેનું તેનું સહજીવન કવકમૂળ કહેવાય અવખંડન ભાજન કલિકાસર્જન પદ્ધતિ ફૂગ વાનસ્પતિક પ્રજનન (પ૯૭૯ણપ૦ કશીબીજાણુઓ ચલબીજાણુઓ જૈવિક વર્ગીકરણ (ાંળ્યાં હંઘડકાંડિવ્યા) કહેવાતા બીજાણુઓ અલિંગી પ્રજનન તથા અંડબીજાણુઓ ધાનીબીજાણુઓ પ્રકણીબીજાણુઓ દારા લિંગી પ્રજનન ફળકાય (પં છ કહેવાતી વિશિષ્ટ રચનાઓમાં વિવિધ પ્રકારના બીજાણુઓ ઉત્પન્ન થાય લિંગી ચક્રમાં નીચેના ત્રણ તબક્કાઓ સમાવેશિત જીવરસ સંયુગ્મન બે ચલિત અચલિત જન્યુઓ વચ્ચેના જીવરસના જોડાણને જીવરસ સંયુગ્મન કહે કોષકેન્દ્ર સંયુગ્ભન બે કોપકેનદ્રોના જોડાણને કોષકેનદ્ર સંયુગ્મન કહે અર્ધીકરણ (૦ડાંડ) ફલિતાંડમાં અર્ધાકિરણ ઠિયા થવાને પરિણામે એકકીય બીજાણુઓ ઉત્પન્ન થાય જ્યારે ફૂગમાં લિંગી પ્રજનન થાય ત્યારે પરસપર સમાગમ કરી શકે તેવા હરીક પ્રકારોના બે એકકીય કવકસૂત્રો એકબીજાની પાસે આવી જોડાય કેટલીક ફૂગમાં બે એકકીય કોષોનું જોડાણ થવાથી તરત દ્િિકીય કોષો()માં પરિણમે તેમ છતાં આસ્કોમાયસેટીસ બેસિડીયોમાયસેટીસ વર્ગની ફગમાં મધ્યવર્તી દ્રિકોષકેન્દ્રીય અવસ્થા લોંધલાઝ/ બાહ ડાથછ) બને દરેક કોષમાં બે કોપકેનદ્રો) આવી સ્થિતિને દ્િકોષકેન્્દ્રીકરણ હે તબક્કાને હિકોષકેનદ્રી તબક્કો કહે પછી, પિતૃ કોષકેન્્દ્રો જોડાય કોષ હિકીય (તાં[)ઢાંત) બને ફૂગ ફળકાયો જેમાં અર્ધીકરણ વિભાજત્ત થવાથી એકકીય બીજાણુઓ([ંત નિર્માણ થાય કવકજાળની બાહ્યાકાર રચના, બીજાણુ નિર્માણનો પ્રકાર ફળકાયોના નિર્માણને આધારે સૃષ્ટિને વિવિધ વર્ગોમાં વિભાજિત કરવામાં આવે ફાયકોમાયસેટીસ ફાયકોમાયસેટીસના સભ્યો જલજ નિવાસસ્થાનોમાં જોવા મળે તેમજ ભીના ભેજયુક્ત વિસ્તારોમાં સડતા લાકડાઓ અવિકલ્પી પરોપજીવીઓ તરીકે વનસ્પતિઓ જોવા મળે કવકજાળ પડદાવિહીન (ઢડલૂપથાટ) બહુકોષકેન્દ્રીય ચલબીજાણુ અચલબીજાણુ (અચલિત- અલિંગી પ્રજનન બીજાણુધાનીમાં બીજાણુઓ અંતર્જાત (લાલં૦ણ૦) રીતે ઉત્પન્ન થાય બે જન્યુઓના જોડાણથી યુગ્મબીજાણુઓ બને પ્રકારના જન્યુઓ જો બાદ્યાકાર રીતે સરખા સમજન્યુક સરખા ન વિષમજન્યુક અંડજગ્યુક મ્યુકર (આકૃતિ રાઇઝોપસ આલબ્યુગો થતી પરોપજીવી ફૂગ) કેટલાક સામાનય ઉદાહરણો આસ્કોમાયસેટીસ સામાન્ય રીતે વર્ગના સભ્યો કોથળીમય ફૂગ (ડ૦-૫છાં) તરીકે જાણીતા આસ્કોમાયસેટીસ વર્ગના સભ્યો મુખ્યત્વે બહુકોષીય, દા પેનિસિલિયમ ભાગ્યે એકકોષીય, દા તેઓ મૃતોપજીવીઓ વિઘટકો પરોજીવીઓ છાણભક્ષીઓ છાણ વિકાસ પામતા) તરીકે કવકજાળ મ્યુકર એસ્પરજીલસ એગેરિક્સ આકૃતિ ફૂગ જીવવિજ્ઞાન શાખિત પડદાયુક્ત કણીબીજાણુધાનીધર કહેવાતી વિશિષ્ટ કવકજાળ ઉપર બઢિર્જાત રીતે કણીબીજાણુઓ તરીકે અલિંગી બીજાણુઓ ઉત્પન થાય કણીબીજાણુઓના અંકુરણથી નવી કવકજાળ બને કોથળી જેવી ધાનીઓ(ઘડટો)માં અંતર્જાત રીતે લિંગી બીજાણુઓ ઉત્પન્ન થાય જેને ધાનીબીજાણુઓ કહે ધાનીઓ વિશિષ્ટ પ્રકારના ફળકાયમાં ગોઠવાયેલી જેને ફળધાનીકાય કહે એસ્પરજીલસ (આકૃતિ ક્લેવિસેપ્સ ન્યુરોસ્પોરા તેના કેટલાક ઉદાહરણો જૈવરસાયણ જનીન ક્રિયાવિધિમાં નયુરોસ્પોરા ખૂબજ ઉપયોગી કાળા રંગ ાાંડ-મોરેલ્સ) પીળા રંગ (ઈદ ૯ડ-બફલ્સ)ના ઘણા સભ્યો ખાવાલાયક સુસ્વાદુ વાનગી તરીકે માનવામાં આવે બેસિડીયોમાયસેટીસ સામાન્ય રીતે બેસિડીયોમાયસેટીસ વર્ગના જાણીતા સ્વરૂપો મશરૂમ, બ્રેકેટ ફંજાઈ (લદ પાળા) પફબોલ્સ તરીકે તેઓ જમીનમાં, લાકડાના ગોળવા પર, ઝાડના થડ વત્તસ્પતિઓના દેહની અંદર પરોપજીવી તરીકે જીવન ગુજારે ગેરુ અંગારિયો તેની કવકજાળ શાખિત પડદાયુક્ત અલિંગી બીજાણુઓ સામાન્ય રીતે જોવા મળતા નથી પરંતુ અવખંડન દારા થતું વાનસ્પતિક પ્રજનન સામાન્ય લિંગી અંગો ગેરહાજર પરંતુ અલગ પ્રકારના વિભેદો જનીન પ્રકારોના બે વાનસ્પતિક દૈહિક કોષો( વ૯)ના જોડાણ જીવરસ સંયુગ્મન થાય આના પરિણામે હિકોષકેન્દ્રી રચના બને જે અંતે પ્રકણીબીજાણુધાની (ઇડાંતાં॥) તરીકે વિકાસ પામે પ્રકણીધાનીમાં કોષકેન્દ્ર સંયુગ્મન અર્ધાકરણ થવાથી ચાર પ્રકણીબીજાણુઓ (ાંતાં[) ઉત્પન્ન થાય પ્રકણીબીજાણુઓ પ્રકણીબીજાણુધાની બહિર્જાત રીતે ઉત્પન્ન થાય પ્રકણીબીજાણુધાનીઓ ફળકાયોમાં ગોઠવાયેલી છે, જેને પ્રકણીધાનીકાયો (ઇાંતા૦૦ળ)) કહે એગેરિક્સ (આકૃતિ યુસ્ટીલાગો અંગારિયા જવાબદાર ફૂગ) પશ્સિતિયા જવાબદાર ફૂગ) સામાન્ય રીતે વર્ગના સભ્યો ડ્યુટરોમાયસેટીસ સામાન્ય રીતે અપૂર્ણ ફૂગ તરીકે જાણીતી કારણ ફૂગના માત્ર અલિંગી વાનસ્પતિક તબક્કાઓ ઓળખાયા જયારે ફૂગના લિંગી સ્વરૂપો શોધાયા ત્યારે તેને સાચી રીતે સમાવેશિત થાય તેવા વર્ગોમાં મૂકવામાં આવી હતી શક્ય તેની અલિંગી વાનસ્પતિક અવસ્ ...
#   3. '-ફાયકોઇરીશ્રીન પ્રભાવિતા મોટે ભાગે રાતી લીલ દરિયાઈ જે હુંફાળા ખારા પાણીમાં વધુ જોવા મળે તેઓ પાણીની સપાટી નજીક વધુ સારા પ્રકાશિત વિસ્તારમાં મહાસાગરોમાં વધુ ઊંડાઈએ જ્યાં સાપેક્ષ રીતે ખૂબ ઓછો પ્રકાશ પ્રવેશે તેવા વિસ્તારોમાં એમ બંને સ્થાને થાય મોટે ભાગે રાતી લીલનું સુકાય બહુકોષીય તેમાંની કેટલીક જાટેલ દૈહિક આયોજન ધરાવે તેમાં ખોરાકનો સંગ્રહ ફલોરિડીઅન સ્ટાર્ચ (ંતાંથ ડૉહ્ાલ) સ્વરૂપે થાય જે બંધારણમાં એમાયલોપેક્ટીન ગ્લાયકોજનને ઘણું મળતું આવે રાતી લીલ સામાન્યતઃ અવખંડન વાનસ્પતિક પ્રજનન તેઓ અચલિત બીજાણુઓ અલિંગી રીતે અચલિત જન્યુઓ લિંગી રીતે પ્રજનન લિંગી પ્રજનન અંડજન્યુક પ્રકારે થાય તેની કોષ્ટક લીલના વિભાગો તેમની મુખ્ય લાક્ષણિકતાઓ વર્ગો સામાન્ય મુખ્ય ખોરાક કોષદીવાલ કશાતી સંખ્યા તિવાસસ્થાન ત્તામ રંજકદ્રવ્યો સંગ્રહ પ્રવેશની સ્થિતિ ક્લોરોફાયસી લીલી લીલ ક્લોરોફીલ છ સ્ટાર્ચ સેલ્યુલોઝ સમાન, મીઠું પાણી, થોડુંક ખારું ફીઓફાયસી બદામી લીલ ક્લોરોફીલ ફયુકોઝેન્થીન ડોફાયસી રાતી લીલ ક્લોરોકીલ દ તં ફાયકોઇરીશ્રીન મેનિટોલ લેમિનારિન ફલોરિડીઅન સ્ટાર્ચ સેલ્યુલોઝ આજિન સેલ્યુલોઝ, પેકટીન પોલીસલ્ફેટ એસ્ટર અગ્રસ્થ અસમાન પાર્શીય ગેરહાજર પાણી, ક્ષારયુક્ત પાણી મીઠું પાણી (ભાગ્યે થોડુંક ખારું પાણી, ક્ષારયુક્ત પાણી મીઠું પાણી કેટલાક) થોડુંક ખારું પાણી, ક્ષારયુક્ત પાણી (મુખ્યત્વે) જીવવિજ્ઞાન સાથે જટિલ પશ્ચ-ફલન હિ વિકાસ થાય પોલીસાઇકોનિયા ગ્રેસિલારિયા જેલિડિયમ તેના સામાન્ય સભ્યો દ્દિઅંગીઓ હિઅંગી વનસ્પતિઓમાં વિવિધ મોસ લીવરવર્ટ (પ૪૦)નો સમાવેશ થાય જે ટેકરીઓમાં ભેજયુક્ત છાયાપ્રિય વિસ્તારોમાં સામાન્ય રીતે વિકાસ પામતી જોવા મળે (આકૃતિ દ્રિઅંગીઓને વનસ્પતિ સૃષ્ટિના ઉભયજીવીઓ કહે છે, કારણ પુંજન્યુધાનીધર સ્ત્રીજન્યુધાનીધર કુડમલી પ્યાલો કુડમલી પ્યાલો મૂલાંગો મૂલાંગો પુંજન્યુધાની ધારણ કરતી શાખા પ્રાવર શાખાઓ બીજાણુજનક સ્ત્રીજન્યુધાની ધારણ કરતી જન્યુજનક શાખા મુખ્ય અક્ષ મૂલાંગો આકૃતિ હિઅંગીઓ લીવરવર્ટ-માર્કેનશિયા માદા સુકાય નર સુકાય મોસ યુનારિયા, જન્યુજનક બીજાણુજનક સફેગ્તમ જન્યુજનક વનસ્પતિ સૃષ્ટિ વનસ્પતિઓ જમીન જીવિત રહી શકે પરંતુ લિંગી પ્રજનન પાણી આધારિત તેઓ હંમેશાં ભીની, ભેજયુક્ત છાયાવાળા સ્થાને થાય તેઓ વેરાન (ઉજ્જડ) ખડકો જમીન વનસ્પતિ અનુકરમણમાં મહત્ત્વનો ભાગ ભજવે દ્રિઅંગીઓનો વનસ્પતિ દેહ લૌલના વાનસ્પતિક દેહ કરતાં ખૂબ વિભેદિત (તાંતિટાલાંથાટત) સુકાય જેવો તેનું સુકાય પથરાયેલ ટટાર તથા એકકોષીય બહુકોષીય મૂલાંગો આધારક સાથે જોડાયેલું રહે તેઓ સાચા મૂળ, પ્રકાંડ પર્ણો ધરાવતા નથી તેઓ મૂળ જેવી, પર્ણ જેવી પ્રકાંડ જેવી રચનાઓ ધરાવી શકે દ્રિઅંગીઓનો મુખ્ય વનસ્પતિ દેહ એકકીય જન્યુઓ ઉત્પન્ન તેથી તેને જન્યુજનક કહે દિઅંગીઓમાં લિંગી અંગો બહુકોષીય તનર લિંગી અંગને પુંજગ્યુધાની (શ૯ંલાં॥) કહે તેઓ દરિકશાધારી ચલપુંજન્યુઓ ઉત્પન્ન રે માદા લિંગી અંગને સ્ત્રીજન્યુધાની કહે જે ચંબુ આકારની અંડકોષ ઉત્પન્ન ચલપુંજન્યુઓ પાણીમાં મુક્ત કરવામાં આવે જ્યાં તેઓ સ્ત્રીજન્યુધાનીના સંપર્કમાં આવે ચલપુંજન્યુઓ અંડકોષ સાથે જોડાઈને કલિતાંડ()/- યુગ્મનજ)નું નિર્માણ ફલિતાંડ ત્વરિત રીતે અર્ધાકરણ (॥ંડાંડ) દાખવતું નથી તેઓ બહુકોષીય દેહનું નિર્માણ જેને બીજાણુજનક કહે બીજાણુજનક મુક્તજીવી તનથી પરંતુ પ્રકાશસંશ્લેષી જન્યુજનક સાથે જોડાયેલો રહે તેમાંથી તેનું પોષણ મેળવે બીજાણુજનકના કેટલાક કોષો અર્ધીકરણ પામી એકકીય બીજાણુઓનું નિર્માણ બીજાણુઓ અંકુરિત થઈ જન્યુજનક ઉત્પન્ન સામાન્યતઃ દ્વિઅંગી વનસ્પતિઓની આર્થિક અગત્યતા ઓછી પરંતુ કેટલાક મોસ તૃણાહારી સ્તનો પક્ષીઓ અન્ય પ્રાણીઓ ખોરાક પૂરો પાડે સ્ફેગ્નમની કેટલીક જાતિ, મોસ વગેરે (પાણીની અસરથી સડીને લોચો થઈ ગયેલ વનસ્પતિજન્ય પદાર્થ) પૂરા પાડે જે લાંબા સમય સુધી બળતણ તરીકે ઉપયોગમાં લેવાય પાણીને રોકવાની તેમની ક્ષમતાને કારણે જીવંત પદાર્થોની જરૂરી હેરફેર સામગ્રી બાંધવા તરીકે(ઘડ [)થંલ૧છ ાલાપંથ)ની ઉપયોગિતા મોસ લાઇકેન્સની સાથે વસાહતી ખડકો માટેના પ્રથમ સજીવો તેથી, તેમનું પરિસ્થિતિકીય દષ્ટિએ ખૂબ મહત્ત્વ તેઓ ખડકોનું વિઘટન કરી ઉચ્ચ વનસ્પતિઓને ઉગવા (વિકાસ પામવા) માટેનો સાનુકળ આધાર જયારે મોસ જમીન ગહન સાદડી જેવું અસ્તર છે, ત્યારે તેઓ વરસતા વરસાદ શિ॥)ની અસરને ઘટાડી જમીનનું ધોવાણ થતું અટકાવે હિઅંગીઓને, લીવરવર્ટ મોસ એમ બે ભાગમાં વિભાજિત કરવામાં આવે લીવરવર્ટ સામાન્યતઃ ભેજયુક્ત, છાયાપ્રિય નિવાસસ્થાનોમાં વિકાસ પામે જેવા પાણીના પ્રવાહો (ઝરણાં, નદો વગેરે)ના કિનારે, ભેજવાળા મેદાનોમાં, ભીની જમીન પર, વૃક્ષોની છાલ લાકડાઓના ગર્તામાં લીવરવર્ટનો વનસ્પતિ દેહ સુકાયક છે, દા માર્કેન્શિયા સુકાય પૃષ્ઠ-વક્ષીય (તહાં) ગાઢ રીતે આધાર સાથે ચોંટેલું પત્રમય સભ્યો પ્રકાંડ જેવી રચના બે હરોળ(પંક્તિ)માં પર્ણ જેવી નાની નાની સંરચનાઓ (પાંગો) ધરાવે લીવરવર્ટમાં અલિંગી પ્રજન ...

# %%
# Cell 7 - Challenges Analysis (GOOD)
def analyze_indian_language_challenges():
    """
    Analyze specific challenges in parsing Indian languages like Gujarati
    """
    print("ANALYSIS OF PARSING CHALLENGES FOR INDIAN LANGUAGES")
    print("=" * 60)
    
    challenges = {
        "Morphological Richness": [
            "Gujarati has rich morphology with complex verb conjugations",
            "Nouns have gender (masculine, feminine, neuter) and case markers",
            "Agglutinative nature leads to long compound words"
        ],
        "Word Order Flexibility": [
            "Relatively free word order compared to English",
            "SOV (Subject-Object-Verb) is common but not fixed",
            "Postpositions instead of prepositions"
        ],
        "Resource Scarcity": [
            "Limited annotated corpora for training parsers",
            "Few pre-trained models for Gujarati syntax analysis",
            "Lack of comprehensive grammar formalisms"
        ],
        "Technical Challenges": [
            "Tokenization issues with compound words",
            "POS tagging ambiguity",
            "Handling of vibhakti (case markers) and samasa (compounds)"
        ]
    }
    
    for challenge, issues in challenges.items():
        print(f"\n{challenge}:")
        for issue in issues:
            print(f"  • {issue}")
    
    print("\n" + "=" * 60)
    print("RECOMMENDATIONS:")
    print("1. Develop language-specific grammar rules")
    print("2. Create annotated corpora for Gujarati")
    print("3. Use rule-based approaches combined with statistical methods")
    print("4. Focus on chunking before full parsing")
    print("5. Collaborate with linguists for grammar formalisms")

# Run the challenges analysis
analyze_indian_language_challenges()
# Out:
# ANALYSIS OF PARSING CHALLENGES FOR INDIAN LANGUAGES
# ============================================================
#
# Morphological Richness:
#   • Gujarati has rich morphology with complex verb conjugations
#   • Nouns have gender (masculine, feminine, neuter) and case markers
#   • Agglutinative nature leads to long compound words
#
# Word Order Flexibility:
#   • Relatively free word order compared to English
#   • SOV (Subject-Object-Verb) is common but not fixed
#   • Postpositions instead of prepositions
#
# Resource Scarcity:
#   • Limited annotated corpora for training parsers
#   • Few pre-trained models for Gujarati syntax analysis
#   • Lack of comprehensive grammar formalisms
#
# Technical Challenges:
#   • Tokenization issues with compound words
#   • POS tagging ambiguity
#   • Handling of vibhakti (case markers) and samasa (compounds)
#
# ============================================================
# RECOMMENDATIONS:
# 1. Develop language-specific grammar rules
# 2. Create annotated corpora for Gujarati
# 3. Use rule-based approaches combined with statistical methods
# 4. Focus on chunking before full parsing
# 5. Collaborate with linguists for grammar formalisms

# %%
# Cell 8 - Export Results (NEEDS FIX)
def export_parse_tree_results(sentences, output_file):
    """
    Export parse tree analysis results
    """
    # Create output directory if needed
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    grammar = create_enhanced_gujarati_grammar()
    
    results = []
    for sentence in sentences:
        words = sentence.split()
        tree = parse_gujarati_sentence(sentence, grammar)
        
        result = {
            'sentence': sentence,
            'word_count': len(words),
            'parse_success': tree is not None,
            'sentence_complexity': 'Simple' if len(words) <= 5 else 'Complex'
        }
        results.append(result)
    
    # Write results
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write("PARSE TREE ANALYSIS RESULTS\\n")
            f.write("=" * 50 + "\\n\\n")
            
            success_count = sum(1 for r in results if r['parse_success'])
            f.write(f"Total sentences analyzed: {len(results)}\\n")
            f.write(f"Successfully parsed: {success_count}\\n")
            f.write(f"Success rate: {success_count/len(results):.2%}\\n\\n")
            
            f.write("DETAILED ANALYSIS:\\n")
            f.write("-" * 50 + "\\n")
            
            for i, result in enumerate(results, 1):
                status = "✓" if result['parse_success'] else "✗"
                f.write(f"{i}. {status} {result['sentence_complexity']:>8}: {result['sentence']}\\n")
        
        print(f"✅ Results exported to: {output_file}")
        return results
        
    except Exception as e:
        print(f"❌ Error exporting results: {e}")
        return results

# Export results using our sample sentences
output_results_file = './parse_tree_analysis.txt'
results = export_parse_tree_results(gujarati_sentences, output_results_file)

print(f"\\nFinal Summary:")
print(f"Analyzed {len(results)} sentences")
success_count = sum(1 for r in results if r['parse_success'])
print(f"Success rate: {success_count/len(results):.1%}")
# Out:
# ✅ Results exported to: ./parse_tree_analysis.txt
# \nFinal Summary:
# Analyzed 8 sentences
# Success rate: 37.5%
